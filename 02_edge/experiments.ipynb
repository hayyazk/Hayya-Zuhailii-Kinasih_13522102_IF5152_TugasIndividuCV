# %% [markdown]
# # Edge Detection

# %%
from skimage import data
from sobel import sobelThreshold
from canny import cannySigma

images = [data.camera(), data.coins(), data.checkerboard(), data.chelsea()]

# %%
sobelThreshold(images, [3, 5, 8, 10, 15])

# %%
cannySigma(images, [1, 2, 3, 4, 5])
