# %% [markdown]
# # Geometri

# %%
from skimage import data
import numpy as np
from transformasi import transformasi

images = [data.camera(), data.coins(), data.checkerboard(), data.chelsea()]

# %%
src_pts = np.array([[0,0],[399,0],[399,299],[0,299]], dtype=np.float32)
dst_pts = np.array([[50,30],[370,40],[360,280],[80,260]], dtype=np.float32)
transformasi(images, src_pts, dst_pts)
# Out:
# [[ 7.52474658e-01  1.38046704e-01  5.00000000e+01]
#  [ 1.97080238e-02  8.91795600e-01  3.00000000e+01]
#  [-1.33865822e-04  4.71403194e-04  1.00000000e+00]]
# [[ 7.52474658e-01  1.38046704e-01  5.00000000e+01]
#  [ 1.97080238e-02  8.91795600e-01  3.00000000e+01]
#  [-1.33865822e-04  4.71403194e-04  1.00000000e+00]]
# [[ 7.52474658e-01  1.38046704e-01  5.00000000e+01]
#  [ 1.97080238e-02  8.91795600e-01  3.00000000e+01]
#  [-1.33865822e-04  4.71403194e-04  1.00000000e+00]]
# [[ 7.52474658e-01  1.38046704e-01  5.00000000e+01]
#  [ 1.97080238e-02  8.91795600e-01  3.00000000e+01]
#  [-1.33865822e-04  4.71403194e-04  1.00000000e+00]]
