# %% [markdown]
# # Filtering Experiments

# %%
from skimage import data
from gaussian import gaussianStrength, gaussianMode
from median import medianSize, medianMode

images = [data.camera(), data.coins(), data.checkerboard(), data.chelsea()]

# %%
gaussianStrength(images, [10, 25, 50])

# %%
medianSize(images, [10, 25])

# %%
gaussianMode(images, ['reflect', 'constant', 'nearest', 'mirror', 'wrap'], 25)

# %%
medianMode(images, ['reflect', 'constant', 'nearest', 'mirror', 'wrap'], 10)
